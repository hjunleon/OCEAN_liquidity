# %%
import pandas as pd
import json
import urllib.request
import math
import sys
import requests
from pprint import pprint

# %%
pd.options.display.max_columns = None
pd.options.display.max_rows = None

# %%
# Terms:
#  Dollar Volume Liquidity:  is a stock's share price multiplied by its daily share volume.

# Liquidity vs. Volume Trading volume is simply a measure of the value of executed trades within a period of time, typically measured on a daily basis. Liquidity, on the other hand, has more to do with the buy and sell orders that are currently on the order books. In other words, volume is a measurement of the trades that have already taken place, while liquidity informs the buy and sell offers that can currently be accepted on the exchange.

# %%
# Links
# https://cryptomarketpool.com/use-the-graph-to-query-ethereum-data-in-python/
# https://hasura.io/docs/latest/queries/postgres/sorting/
# https://www.marketcalls.in/trading-lessons/understand-basic-difference-liquidity-volume.html
# https://www.cryptovantage.com/guides/what-does-liquidity-mean-for-cryptocurrency/

# %%
# URL = "https://api.thegraph.com/subgraphs/name/uniswap/uniswap-v3"
url = "https://api.thegraph.com/subgraphs/name/uniswap/uniswap-v3"

# %%
# Convert Uniswap v3 tick to a price (i.e. the ratio between the amounts of tokens: token1/token0)
def tick_to_price(tick):
    return TICK_BASE ** tick

# Not all ticks can be initialized. Tick spacing is determined by the pool's fee tier.
def fee_tier_to_tick_spacing(fee_tier):
    return {
        100: 1,
        500: 10,
        3000: 60,
        10000: 200
    }.get(fee_tier, 60)
# function to use requests.post to make an API call to the subgraph url
def run_query(q):

    # endpoint where you are making the request
    request = requests.post(url,
                            '',
                            json={'query': query})
    if request.status_code == 200:
        return request.json()
    else:
        raise Exception('Query failed. return code is {}.      {}'.format(request.status_code, query))

# %%
# Top 20 tokens by TVL

# %%
# Get top N pools by totalValueLockedUSD

N = 50
pool_ids = {}
#query pools($top_n: ID!){
# Following link teaches how to query using graphql
# https://hasura.io/docs/latest/queries/postgres/sorting/

query = """
{
    pools(
        first: $top_n
        orderBy:totalValueLockedUSD
        orderDirection: desc
      ) {
        id
        createdAtTimestamp
        tick
        token0 {
          symbol
          name
          decimals
          totalSupply
          totalValueLocked
          totalValueLockedUSD
          volumeUSD
          feesUSD
        }
        token1 {
          symbol
          name
          decimals
          totalSupply
          totalValueLocked
          totalValueLockedUSD
          volumeUSD
          feesUSD
        }
        collectedFeesUSD
        collectedFeesToken0
        collectedFeesToken1
        feeTier
        feesUSD
        liquidity
        liquidityProviderCount
        token0Price
        token1Price
        totalValueLockedUSD
        totalValueLockedToken0
        totalValueLockedToken1
        volumeToken0
        volumeToken1
        volumeUSD

  } 
}
"""

# Query the subgraph
# req = urllib.request.Request(URL)
# req.add_header('Content-Type', 'application/json; charset=utf-8')
# jsondata = {"query": query, "variables": {"top_n": N}}
# jsondataasbytes = json.dumps(jsondata).encode('utf-8')
# req.add_header('Content-Length', len(jsondataasbytes))
# response = urllib.request.urlopen(req, jsondataasbytes)
# obj = json.load(response)
# print(obj)

result = run_query(query)

# %%
# print the results
print('Print Result - {}'.format(result))
print('#############')
# Out:
# Print Result - {'data': {'pools': [{'id': '0x277667eb3e34f134adf870be9550e9f323d0dc24', 'createdAtTimestamp': '1663808675', 'tick': '-161389', 'token0': {'symbol': 'ease.org', 'name': 'Ease Fun Token', 'decimals': '18', 'totalSupply': '28368', 'totalValueLocked': '1003900.001085209227447215', 'totalValueLockedUSD': '1109778722632.18178148433647518817', 'volume': '0.000003', 'volumeUSD
': '28368', 'totalValueLocked': '1003900.001085209227447215', 'totalValueLockedUSD': '1109778722632.18178148433647518817', 'volume': '0.000003', 'volumeUSD': '1.141758918984956706118360126972235', 'feesUSD': '0.0001141758918984956706118360126972235'}, 'token1': {'symbol': 'ez-SLP-WBTC-WETH', 'name': 'WBTC-WETH SLP Ease Vault', 'decimals': '18', 'totalSupply': '18368', 'totalValueLocked': '0.000000000011998846', 'totalValueLockedUSD': '0', 'volume': '0', 'volumeUSD': '0', 'feesUSD ...
# #############

# %%
pprint(result)
# Out:
# {'data': {'pools': [{'createdAtTimestamp': '1663808675',
#                      'feeTier': '100',
#                      'feesUSD': '0',
#                      'id': '0x277667eb3e34f134adf870be9550e9f323d0dc24',
#                      'liquidity': '313521001529099829406',
#                      'liquidityProviderCount': '0',
#                      'tick': '-161389',
#                      'token0': {'decimals': '18',
#                                 'feesUSD': '0.0001141758918984956706118360126972235',
#                                 'name': 'Ease Fun Token',
#                                 'symbol': 'ease.org',
#                                 'totalSupply': '28368',
#                                 'totalValueLocked': '1003900.001085209227447215',
#                                 'totalValueLockedUSD': '1109778722632.18178148433647518817',
#                                 'volume': '0.000003',
#                                 'volumeUSD': '1.141758918984956706118360126972235'},
#                      'token0Price': '10201983.52821130596040573863212092',
#                      'token1': {'decimals': '18',
#                                 'feesUSD': '0',
#                                 'name': 'cvxsteCRV Ease Vault',
#                                 'symbol': 'ez-cvxsteCRV',
#                                 'totalSupply': '18368',
#                                 'totalValueLocked': '0.098157689878957356',
#                                 'totalValueLockedUSD': '0',
#                                 'volume': '0.000000000000108977',
#                                 'volumeUSD': '0'},
#                      'token1Price': '0.00000009802015433907763482013950488687576',
#                      'totalValueLockedToken0': '1001400.000100999992665055',
#                      'totalValueLockedToken1': '0.098157689878957355',
#                      'totalValueLockedUSD': '1110167010695.785900004139211677005'},
#                     {'createdAtTimestamp': '1625360210',
#                      'feeTier': '500',
#                      'feesUSD': '0',
#                      'id': '0xa850478adaace4c08fc61de44d8cf3b64f359bec',
#                      'liquidity': '1706245281880037395956227425',
#                      'liquidityProviderCount': '0',
#                      'tick': '46048',
#                      'token0': {'decimals': '18',
#                                 'feesUSD': '6.271907994682834462724163690131096',
#                                 'name': 'UMIIE COIN',
#                                 'symbol': 'UMIIE',
#                                 'totalSupply': '28240',
#                                 'totalValueLocked': '4060050480.115629263002904667',
#                                 'totalValueLockedUSD': '1418175887838.43006967093349508692',
#                                 'volume': '1000111.36015031931450555',
#                                 'volumeUSD': '2234.275824537063717565341059307139'},
#                      'token0Price': '0.01000586374960270227477201921193648',
#                      'token1': {'decimals': '18',
#                                 'feesUSD': '0',
#                                 'name': 'Umiie 2',
#                                 'symbol': 'UMIIE2',
#                                 'totalSupply': '18240',
#                                 'totalValueLocked': '14644676667.240849617715772909',
#                                 'totalValueLockedUSD': '0',
#                                 'volume': '99930988.660196871689931931',
#                                 'volumeUSD': '0'},
#                      'token1Price': '99.94139686738253752770898237370869',
#                      'totalValueLockedToken0': '50050480.103497613002904654',
#                      'totalValueLockedToken1': '14644676667.240849617715772909',
#                      'totalValueLockedUSD': '12887625156.60443191907094774602519'},
#                     {'createdAtTimestamp': '1663808063',
#                      'feeTier': '100',
#                      'feesUSD': '0',
#                      'id': '0x8c0411f2ad5470a66cb2e9c64536cfb8dcd54d51',
#                      'liquidity': '40740981393984479118',
#                      'liquidityProviderCount': '0',
#                      'tick': '-69281',
#                      'token0': {'decimals': '18',
#                                 'feesUSD': '0.0001141758918984956706118360126972235',
#                                 'name': 'Ease Fun Token',
#                                 'symbol': 'ease.org',
#                                 'totalSupply': '28368',
#                                 'totalValueLocked': '1003900.001085209227447215',
#                                 'totalValueLockedUSD': '1109778722632.18178148433647518817',
#                                 'volume': '0.000003',
#                                 'volumeUSD': '1.141758918984956706118360126972235'},
#                      'token0Price': '1020.197309047320743679301892429615',
#                      'token1': {'decimals': '18',
#                                 'feesUSD': '0',
#                                 'name': 'yvCurve-IronBank Ease Vault',
#                                 'symbol': 'ez-yvCurve-IronBank',
#                                 'totalSupply': '18368',
#                                 'totalValueLocked': '1.275526246490417916',
#                                 'totalValueLockedUSD': '0',
#                                 'volume': '0.000000000989903616',
#                                 'volumeUSD': '0'},
#                      'token1Price': '0.0009802025462445285537950420182116627',
#                      'totalValueLockedToken0': '1300.000100909928897755',
#                      'totalValueLockedToken1': '1.275526246490417916',
#                      'totalValueLockedUSD': '1432077483.208630196467118329099649'},
#                     {'createdAtTimestamp': '1663808363',
#                      'feeTier': '100',
#                      'feesUSD': '0',
#                      'id': '0x055284a4ca6532ecc219ac06b577d540c686669d',
#                      'liquidity': '0',
#                      'liquidityProviderCount': '0',
#                      'tick': None,
#                      'token0': {'decimals': '18',
#                                 'feesUSD': '0.0001141758918984956706118360126972235',
#                                 'name': 'Ease Fun Token',
#                                 'symbol': 'ease.org',
#                                 'totalSupply': '28368',
#                                 'totalValueLocked': '1003900.001085209227447215',
#                                 'totalValueLockedUSD': '1109778722632.18178148433647518817',
#                                 'volume': '0.000003',
#                                 'volumeUSD': '1.141758918984956706118360126972235'},
#                      'token0Price': '0',
#                      'token1': {'decimals': '18',
#                                 'feesUSD': '0',
#                                 'name': 'WBTC-WETH SLP Ease Vault',
#                                 'symbol': 'ez-SLP-WBTC-WETH',
#                                 'totalSupply': '18368',
#                                 'totalValueLocked': '0.000000000011998846',
#                                 'totalValueLockedUSD': '0',
#                                 'volume': '0',
#                                 'volumeUSD': '0'},
#                      'token1Price': '0',
#                      'totalValueLockedToken0': '1200.000883299205884404',
#                      'totalValueLockedToken1': '0.000000000011998846',
#                      'totalValueLockedUSD': '1322031013.848042060988788389158996'},
#                     {'createdAtTimestamp': '1620250931',
#                      'feeTier': '500',
#                      'feesUSD': '176335369.7312392274134553224813291',
#                      'id': '0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640',
#                      'liquidity': '27824787316974085166',
#                      'liquidityProviderCount': '0',
#                      'tick': '201945',
#                      'token0': {'decimals': '6',
#                                 'feesUSD': '532114681.817181633237908037807917',
#                                 'name': 'USD Coin',
#                                 'symbol': 'USDC',
#                                 'totalSupply': '19312',
#                                 'totalValueLocked': '801395568.310042',
#                                 'totalValueLockedUSD': '801395568.310042',
#                                 'volume': '578002542397.742837',
#                                 'volumeUSD': '577854594925.0263620360667153467773'},
#                      'token0Price': '1698.490446887185584214725250244457',
#                      'token1': {'decimals': '18',
#                                 'feesUSD': '1183210897.988011021105904017405557',
#                                 'name': 'Wrapped Ether',
#                                 'symbol': 'WETH',
#                                 'totalSupply': '19848',
#                                 'totalValueLocked': '619211.810301398934441546',
#                                 'totalValueLockedUSD': '1051580807.277610276529651291639711',
#                                 'volume': '333052396.331927194386288771',
#                                 'volumeUSD': '734150905329.2055584971525209729411'},
#                      'token1Price': '0.0005887580950677083204895498392741363',
#                      'totalValueLockedToken0': '206504407.168735',
#                      'totalValueLockedToken1': '92677.860456415387571803',
#                      'totalValueLockedUSD': '363895234.8212010928449184232377324'},
#                     {'createdAtTimestamp': '1620169800',
#                      'feeTier': '3000',
#                      'feesUSD': '208019721.5949497116981142984034039',
#                      'id': '0x8ad599c3a0ff1de082011efddc58f1908eb6e6d8',
#                      'liquidity': '8558213679362796850',
#                      'liquidityProviderCount': '0',
#                      'tick': '201946',
#                      'token0': {'decimals': '6',
#                                 'feesUSD': '532114681.817181633237908037807917',
#                                 'name': 'USD Coin',
#                                 'symbol': 'USDC',
#                                 'totalSupply': '19312',
#                                 'totalValueLocked': '801395568.310042',
#                                 'totalValueLockedUSD': '801395568.310042',
#                                 'volume': '578002542397.742837',
#                                 'volumeUSD': '577854594925.0263620360667153467773'},
#                      'token0Price': '1698.25702575950129012860472691456',
#                      'token1': {'decimals': '18',
#                                 'feesUSD': '1183210897.988011021105904017405557',
#                                 'name': 'Wrapped Ether',
#                                 'symbol': 'WETH',
#                                 'totalSupply': '19848',
#                                 'totalValueLocked': '619211.810301398934441546',
#                                 'totalValueLockedUSD': '1051580807.277610276529651291639711',
#                                 'volume': '333052396.331927194386288771',
#                                 'volumeUSD': '734150905329.2055584971525209729411'},
#                      'token1Price': '0.0005888390183769597572338250018119705',
#                      'totalValueLockedToken0': '164281858.755152',
#                      'totalValueLockedToken1': '80982.152878838352243477',
#                      'totalValueLockedUSD': '301810368.8427692551257789555622563'},
#                     {'createdAtTimestamp': '1620158974',
#                      'feeTier': '3000',
#                      'feesUSD': '62153916.4779745001952768470312026',
#                      'id': '0xcbcdf9626bc03e24f779434178a73a0b4bad62ed',
#                      'liquidity': '2476971529823551261',
#                      'liquidityProviderCount': '0',
#                      'tick': '257048',
#                      'token0': {'decimals': '8',
#                                 'feesUSD': '132210943.5822690122866169615955322',
#                                 'name': 'Wrapped BTC',
#                                 'symbol': 'WBTC',
#                                 'totalSupply': '18240',
#                                 'totalValueLocked': '8276.52640451',
#                                 'totalValueLockedUSD': '204528091.4590481845730795948583376',
#                                 'volume': '2850495.58309392',
#                                 'volumeUSD': '83519364501.31721899994148600365023'},
#                      'token0Price': '0.06872243815054344389454108624163311',
#                      'token1': {'decimals': '18',
#                                 'feesUSD': '1183210897.988011021105904017405557',
#                                 'name': 'Wrapped Ether',
#                                 'symbol': 'WETH',
#                                 'totalSupply': '19848',
#                                 'totalValueLocked': '619211.810301398934441546',
#                                 'totalValueLockedUSD': '1051580807.277610276529651291639711',
#                                 'volume': '333052396.331927194386288771',
#                                 'volumeUSD': '734150905329.2055584971525209729411'},
#                      'token1Price': '14.55128815146806882165860160254078',
#                      'totalValueLockedToken0': '3901.09805404',
#                      'totalValueLockedToken1': '100555.060702258740605802',
#                      'totalValueLockedUSD': '269035278.0462043314533046672687245'},
#                     {'createdAtTimestamp': '1636771503',
#                      'feeTier': '100',
#                      'feesUSD': '1513993.363880054037908533860100188',
#                      'id': '0x5777d92f208679db4b9778590fa3cab3ac9e2168',
#                      'liquidity': '1053530153326768983581694',
#                      'liquidityProviderCount': '0',
#                      'tick': '-276324',
#                      'token0': {'decimals': '18',
#                                 'feesUSD': '61527317.98841803113568991968786631',
#                                 'name': 'Dai Stablecoin',
#                                 'symbol': 'DAI',
#                                 'totalSupply': '18240',
#                                 'totalValueLocked': '240275921.477541695991545732',
#                                 'totalValueLockedUSD': '240275921.477541695991545732',
#                                 'volume': '68489619888.976891834031522564',
#                                 'volumeUSD': '68524356395.81714613975479944686316'},
#                      'token0Price': '0.9999576263817333204707112032314421',
#                      'token1': {'decimals': '6',
#                                 'feesUSD': '532114681.817181633237908037807917',
#                                 'name': 'USD Coin',
#                                 'symbol': 'USDC',
#                                 'totalSupply': '19312',
#                                 'totalValueLocked': '801395568.310042',
#                                 'totalValueLockedUSD': '801395568.310042',
#                                 'volume': '578002542397.742837',
#                                 'volumeUSD': '577854594925.0263620360667153467773'},
#                      'token1Price': '1.000042375413866290592044844350958',
#                      'totalValueLockedToken0': '87587119.6075558416777845',
#                      'totalValueLockedToken1': '125433635.141519',
#                      'totalValueLockedUSD': '213020754.7490748416777845000000001'},
#                     {'createdAtTimestamp': '1620158293',
#                      'feeTier': '500',
#                      'feesUSD': '3556029.526998081001938861818818165',
#                      'id': '0x6c6bc977e13df9b0de53b251522280bb72383700',
#                      'liquidity': '157511743328465786613774',
#                      'liquidityProviderCount': '0',
#                      'tick': '-276321',
#                      'token0': {'decimals': '18',
#                                 'feesUSD': '61527317.98841803113568991968786631',
#                                 'name': 'Dai Stablecoin',
#                                 'symbol': 'DAI',
#                                 'totalSupply': '18240',
#                                 'totalValueLocked': '240275921.477541695991545732',
#                                 'totalValueLockedUSD': '240275921.477541695991545732',
#                                 'volume': '68489619888.976891834031522564',
#                                 'volumeUSD': '68524356395.81714613975479944686316'},
#                      'token0Price': '0.9996291266355379041749264301225148',
#                      'token1': {'decimals': '6',
#                                 'feesUSD': '532114681.817181633237908037807917',
#                                 'name': 'USD Coin',
#                                 'symbol': 'USDC',
#                                 'totalSupply': '19312',
#                                 'totalValueLocked': '801395568.310042',
#                                 'totalValueLockedUSD': '801395568.310042',
#                                 'volume': '578002542397.742837',
#                                 'volumeUSD': '577854594925.0263620360667153467773'},
#                      'token1Price': '1.000371010962546027590947910590986',
#                      'totalValueLockedToken0': '83190458.029376149307028913',
#                      'totalValueLockedToken1': '78184963.303459',
#                      'totalValueLockedUSD': '161375421.332835149307028913'},
#                     {'createdAtTimestamp': '1620246230',
#                      'feeTier': '500',
#                      'feesUSD': '22823063.97617420584973354301207979',
#                      'id': '0x4585fe77225b41b697c938b018e2ac67ac5a20c0',
#                      'liquidity': '3550197068416986801',
#                      'liquidityProviderCount': '0',
#                      'tick': '257050',
#                      'token0': {'decimals': '8',
#                                 'feesUSD': '132210943.5822690122866169615955322',
#                                 'name': 'Wrapped BTC',
#                                 'symbol': 'WBTC',
#                                 'totalSupply': '18240',
#                                 'totalValueLocked': '8276.52640451',
#                                 'totalValueLockedUSD': '204528091.4590481845730795948583376',
#                                 'volume': '2850495.58309392',
#                                 'volumeUSD': '83519364501.31721899994148600365023'},
#                      'token0Price': '0.06870336491029031768396440914249082',
#                      'token1': {'decimals': '18',
#                                 'feesUSD': '1183210897.988011021105904017405557',
#                                 'name': 'Wrapped Ether',
#                                 'symbol': 'WETH',
#                                 'totalSupply': '19848',
#                                 'totalValueLocked': '619211.810301398934441546',
#                                 'totalValueLockedUSD': '1051580807.277610276529651291639711',
#                                 'volume': '333052396.331927194386288771',
#                                 'volumeUSD': '734150905329.2055584971525209729411'},
#                      'token1Price': '14.55532784028488031929302206640127',
#                      'totalValueLockedToken0': '2651.55277777',
#                      'totalValueLockedToken1': '46487.924294950555083504',
#                      'totalValueLockedUSD': '144473158.4662870196023166923971172'},
#                     {'createdAtTimestamp': '1620232628',
#                      'feeTier': '3000',
#                      'feesUSD': '88247277.79912229635626686830709159',
#                      'id': '0x4e68ccd3e89f51c3074ca5072bbac773960dfa36',
#                      'liquidity': '4376761712662532759',
#                      'liquidityProviderCount': '0',
#                      'tick': '-202011',
#                      'token0': {'decimals': '18',
#                                 'feesUSD': '1183210897.988011021105904017405557',
#                                 'name': 'Wrapped Ether',
#                                 'symbol': 'WETH',
#                                 'totalSupply': '19848',
#                                 'totalValueLocked': '619211.810301398934441546',
#                                 'totalValueLockedUSD': '1051580807.277610276529651291639711',
#                                 'volume': '333052396.331927194386288771',
#                                 'volumeUSD': '734150905329.2055584971525209729411'},
#                      'token0Price': '0.0005925986123491554885917156351572563',
#                      'token1': {'decimals': '6',
#                                 'feesUSD': '149273753.6304619810157594630976319',
#                                 'name': 'Tether USD',
#                                 'symbol': 'USDT',
#                                 'totalSupply': '18240',
#                                 'totalValueLocked': '130388279.784317',
#                                 'totalValueLockedUSD': '130388279.784317',
#                                 'volume': '163222783983.42327',
#                                 'volumeUSD': '163525342169.3596900748183408252995'},
#                      'token1Price': '1687.48285797673467759149682226109',
#                      'totalValueLockedToken0': '40317.707969821595022657',
#                      'totalValueLockedToken1': '64683756.311575',
#                      'totalValueLockedUSD': '133153587.1338443629620401147282705'},
#                     {'createdAtTimestamp': '1620287538',
#                      'feeTier': '500',
#                      'feesUSD': '1396840.054559558277125797540398549',
#                      'id': '0xc63b0708e2f7e69cb8a1df0e1389a98c35a76d52',
#                      'liquidity': '17070877553826323946132',
#                      'liquidityProviderCount': '0',
#                      'tick': '-276325',
#                      'token0': {'decimals': '18',
#                                 'feesUSD': '2635651.023403317927784612988974863',
#                                 'name': 'Frax',
#                                 'symbol': 'FRAX',
#                                 'totalSupply': '19312',
#                                 'totalValueLocked': '79592623.222131932843497064',
#                                 'totalValueLockedUSD': '79591483.87093932784512972980108058',
#                                 'volume': '6860179079.356735440283354594',
#                                 'volumeUSD': '6390110247.977617796818851209844777'},
#                      'token0Price': '1.000014314988704727511192726438666',
#                      'token1': {'decimals': '6',
#                                 'feesUSD': '532114681.817181633237908037807917',
#                                 'name': 'USD Coin',
#                                 'symbol': 'USDC',
#                                 'totalSupply': '19312',
#                                 'totalValueLocked': '801395568.310042',
#                                 'totalValueLockedUSD': '801395568.310042',
#                                 'volume': '578002542397.742837',
#                                 'volumeUSD': '577854594925.0263620360667153467773'},
#                      'token1Price': '0.9999856852162112407355126323011326',
#                      'totalValueLockedToken0': '47053487.009149769528135763',
#                      'totalValueLockedToken1': '48451059.880483',
#                      'totalValueLockedUSD': '95503873.329139726356365564840992'},
#                     {'createdAtTimestamp': '1624225823',
#                      'feeTier': '3000',
#                      'feesUSD': '1008570.130856765568508822349868627',
#                      'id': '0x7379e81228514a1d2a6cf7559203998e20598346',
#                      'liquidity': '12919859768218013191450790',
#                      'liquidityProviderCount': '0',
#                      'tick': '36',
#                      'token0': {'decimals': '18',
#                                 'feesUSD': '1183210897.988011021105904017405557',
#                                 'name': 'Wrapped Ether',
#                                 'symbol': 'WETH',
#                                 'totalSupply': '19848',
#                                 'totalValueLocked': '619211.810301398934441546',
#                                 'totalValueLockedUSD': '1051580807.277610276529651291639711',
#                                 'volume': '333052396.331927194386288771',
#                                 'volumeUSD': '734150905329.2055584971525209729411'},
#                      'token0Price': '0.9963083426983937309419220453823955',
#                      'token1': {'decimals': '18',
#                                 'feesUSD': '1016801.903065880882605665904890417',
#                                 'name': 'StakeWise Staked ETH2',
#                                 'symbol': 'sETH2',
#                                 'totalSupply': '28240',
#                                 'totalValueLocked': '27405.31277340833706587',
#                                 'totalValueLockedUSD': '46369450.55995960478348739905639406',
#                                 'volume': '213844.606001408101878549',
#                                 'volumeUSD': '352653588.0371524843632945599997615'},
#                      'token1Price': '1.003705336132795810247166208693334',
#                      'totalValueLockedToken0': '16704.703250940190876377',
#                      'totalValueLockedToken1': '24801.715241812002496397',
#                      'totalValueLockedUSD': '70826296.34943976366700149177015535'},
#                     {'createdAtTimestamp': '1620251172',
#                      'feeTier': '500',
#                      'feesUSD': '28783970.46831298900375009869481633',
#                      'id': '0x11b815efb8f581194ae79006d24e0d814b7697f6',
#                      'liquidity': '4327267211984676155',
#                      'liquidityProviderCount': '0',
#                      'tick': '-202007',
#                      'token0': {'decimals': '18',
#                                 'feesUSD': '1183210897.988011021105904017405557',
#                                 'name': 'Wrapped Ether',
#                                 'symbol': 'WETH',
#                                 'totalSupply': '19848',
#                                 'totalValueLocked': '619211.810301398934441546',
#                                 'totalValueLockedUSD': '1051580807.277610276529651291639711',
#                                 'volume': '333052396.331927194386288771',
#                                 'volumeUSD': '734150905329.2055584971525209729411'},
#                      'token0Price': '0.0005923493094496452790951246399925631',
#                      'token1': {'decimals': '6',
#                                 'feesUSD': '149273753.6304619810157594630976319',
#                                 'name': 'Tether USD',
#                                 'symbol': 'USDT',
#                                 'totalSupply': '18240',
#                                 'totalValueLocked': '130388279.784317',
#                                 'totalValueLockedUSD': '130388279.784317',
#                                 'volume': '163222783983.42327',
#                                 'volumeUSD': '163525342169.3596900748183408252995'},
#                      'token1Price': '1688.193071296234018719095365499561',
#                      'totalValueLockedToken0': '22163.802711045340863539',
#                      'totalValueLockedToken1': '30898890.162002',
#                      'totalValueLockedUSD': '68538723.83358223196821947654086476'},
#                     {'createdAtTimestamp': '1620241995',
#                      'feeTier': '3000',
#                      'feesUSD': '36608928.28594892626811104418320331',
#                      'id': '0x99ac8ca7087fa4a2a1fb6357269965a2014abc35',
#                      'liquidity': '3218754422450',
#                      'liquidityProviderCount': '0',
#                      'tick': '55094',
#                      'token0': {'decimals': '8',
#                                 'feesUSD': '132210943.5822690122866169615955322',
#                                 'name': 'Wrapped BTC',
#                                 'symbol': 'WBTC',
#                                 'totalSupply': '18240',
#                                 'totalValueLocked': '8276.52640451',
#                                 'totalValueLockedUSD': '204528091.4590481845730795948583376',
#                                 'volume': '2850495.58309392',
#                                 'volumeUSD': '83519364501.31721899994148600365023'},
#                      'token0Price': '0.00004049443752166827924146268806728962',
#                      'token1': {'decimals': '6',
#                                 'feesUSD': '532114681.817181633237908037807917',
#                                 'name': 'USD Coin',
#                                 'symbol': 'USDC',
#                                 'totalSupply': '19312',
#                                 'totalValueLocked': '801395568.310042',
#                                 'totalValueLockedUSD': '801395568.310042',
#                                 'volume': '578002542397.742837',
#                                 'volumeUSD': '577854594925.0263620360667153467773'},
#                      'token1Price': '24694.74972864871297648238090987608',
#                      'totalValueLockedToken0': '1103.67709384',
#                      'totalValueLockedToken1': '25981678.789706',
#                      'totalValueLockedUSD': '53258785.98056416890457993032098645'},
#                     {'createdAtTimestamp': '1620159368',
#                      'feeTier': '3000',
#                      'feesUSD': '37103714.05465997800893873227553373',
#                      'id': '0xc2e9f25be6257c210d7adf0d4cd6e3e881ba25f8',
#                      'liquidity': '1078193026106138102892156',
#                      'liquidityProviderCount': '0',
#                      'tick': '-74371',
#                      'token0': {'decimals': '18',
#                                 'feesUSD': '61527317.98841803113568991968786631',
#                                 'name': 'Dai Stablecoin',
#                                 'symbol': 'DAI',
#                                 'totalSupply': '18240',
#                                 'totalValueLocked': '240275921.477541695991545732',
#                                 'totalValueLockedUSD': '240275921.477541695991545732',
#                                 'volume': '68489619888.976891834031522564',
#                                 'volumeUSD': '68524356395.81714613975479944686316'},
#                      'token0Price': '1697.173790972918964428454938750972',
#                      'token1': {'decimals': '18',
#                                 'feesUSD': '1183210897.988011021105904017405557',
#                                 'name': 'Wrapped Ether',
#                                 'symbol': 'WETH',
#                                 'totalSupply': '19848',
#                                 'totalValueLocked': '619211.810301398934441546',
#                                 'totalValueLockedUSD': '1051580807.277610276529651291639711',
#                                 'volume': '333052396.331927194386288771',
#                                 'volumeUSD': '734150905329.2055584971525209729411'},
#                      'token1Price': '0.0005892148496040241693205649744658264',
#                      'totalValueLockedToken0': '32139528.880651444812134946',
#                      'totalValueLockedToken1': '11213.803850175429201511',
#                      'totalValueLockedUSD': '51185704.98404799592656861426560689'},
#                     {'createdAtTimestamp': '1620157956',
#                      'feeTier': '3000',
#                      'feesUSD': '12776067.60577627944720280159472484',
#                      'id': '0x1d42064fc4beb5f8aaf85f4617ae8b3b5b8bd801',
#                      'liquidity': '536827356105272981391472',
#                      'liquidityProviderCount': '0',
#                      'tick': '-55933',
#                      'token0': {'decimals': '18',
#                                 'feesUSD': '14432779.44732820024354363379822455',
#                                 'name': 'Uniswap',
#                                 'symbol': 'UNI',
#                                 'totalSupply': '18776',
#                                 'totalValueLocked': '5787194.873123343698933638',
#                                 'totalValueLockedUSD': '36600524.10504939764479052677745469',
#                                 'volume': '396608635.559919710335874386',
#                                 'volumeUSD': '4847614664.327084443374044989886734'},
#                      'token0Price': '268.5246890048002391402208155196481',
#                      'token1': {'decimals': '18',
#                                 'feesUSD': '1183210897.988011021105904017405557',
#                                 'name': 'Wrapped Ether',
#                                 'symbol': 'WETH',
#                                 'totalSupply': '19848',
#                                 'totalValueLocked': '619211.810301398934441546',
#                                 'totalValueLockedUSD': '1051580807.277610276529651291639711',
#                                 'volume': '333052396.331927194386288771',
#                                 'volumeUSD': '734150905329.2055584971525209729411'},
#                      'token1Price': '0.003724052353272155388786584030174597',
#                      'totalValueLockedToken0': '5366882.560601385496143812',
#                      'totalValueLockedToken1': '7255.41230088475890648',
#                      'totalValueLockedUSD': '46263856.64033565707166747423503023'},
#                     {'createdAtTimestamp': '1620159478',
#                      'feeTier': '500',
#                      'feesUSD': '7595430.026593173731804912651598025',
#                      'id': '0x7858e59e0c01ea06df3af3d20ac7b0003275d4bf',
#                      'liquidity': '35710552565403070',
#                      'liquidityProviderCount': '0',
#                      'tick': '-59',
#                      'token0': {'decimals': '6',
#                                 'feesUSD': '532114681.817181633237908037807917',
#                                 'name': 'USD Coin',
#                                 'symbol': 'USDC',
#                                 'totalSupply': '19312',
#                                 'totalValueLocked': '801395568.310042',
#                                 'totalValueLockedUSD': '801395568.310042',
#                                 'volume': '578002542397.742837',
#                                 'volumeUSD': '577854594925.0263620360667153467773'},
#                      'token0Price': '1.00589971196872134302294940324235',
#                      'token1': {'decimals': '6',
#                                 'feesUSD': '149273753.6304619810157594630976319',
#                                 'name': 'Tether USD',
#                                 'symbol': 'USDT',
#                                 'totalSupply': '18240',
#                                 'totalValueLocked': '130388279.784317',
#                                 'totalValueLockedUSD': '130388279.784317',
#                                 'volume': '163222783983.42327',
#                                 'volumeUSD': '163525342169.3596900748183408252995'},
#                      'token1Price': '0.9941348904880640866795415850384174',
#                      'totalValueLockedToken0': '34574397.028995',
#                      'totalValueLockedToken1': '8742952.034806',
#                      'totalValueLockedUSD': '43317349.06380099999999999999999999'},
#                     {'createdAtTimestamp': '1620246635',
#                      'feeTier': '3000',
#                      'feesUSD': '11847003.49051574001892995357411098',
#                      'id': '0x290a6a7460b308ee3f19023d2d00de604bcf5b42',
#                      'liquidity': '3478742758885263809144289',
#                      'liquidityProviderCount': '0',
#                      'tick': '-72473',
#                      'token0': {'decimals': '18',
#                                 'feesUSD': '12564613.60050490734203815372129031',
#                                 'name': 'Matic Token',
#                                 'symbol': 'MATIC',
#                                 'totalSupply': '18240',
#                                 'totalValueLocked': '17940072.10453322597457027',
#                                 'totalValueLockedUSD': '21703493.52138593986313939437462171',
#                                 'volume': '3024657216.280776429398717841',
#                                 'volumeUSD': '4094300554.810726836059618972957444'},
#                      'token0Price': '1403.776468711570057809531610265167',
#                      'token1': {'decimals': '18',
#                                 'feesUSD': '1183210897.988011021105904017405557',
#                                 'name': 'Wrapped Ether',
#                                 'symbol': 'WETH',
#                                 'totalSupply': '19848',
#                                 'totalValueLocked': '619211.810301398934441546',
#                                 'totalValueLockedUSD': '1051580807.277610276529651291639711',
#                                 'volume': '333052396.331927194386288771',
#                                 'volumeUSD': '734150905329.2055584971525209729411'},
#                      'token1Price': '0.0007123641279710517388999301420042615',
#                      'totalValueLockedToken0': '17208666.878054391729781701',
#                      'totalValueLockedToken1': '8391.469806256453673359',
#                      'totalValueLockedUSD': '35069528.57387957741453705073034065'},
#                     {'createdAtTimestamp': '1636825557',
#                      'feeTier': '100',
#                      'feesUSD': '5073125.512637761725853001626704965',
#                      'id': '0x3416cf6c708da44db2624d63ea0aaef7113527c6',
#                      'liquidity': '5209922098045562',
#                      'liquidityProviderCount': '0',
#                      'tick': '-60',
#                      'token0': {'decimals': '6',
#                                 'feesUSD': '532114681.817181633237908037807917',
#                                 'name': 'USD Coin',
#                                 'symbol': 'USDC',
#                                 'totalSupply': '19312',
#                                 'totalValueLocked': '801395568.310042',
#                                 'totalValueLockedUSD': '801395568.310042',
#                                 'volume': '578002542397.742837',
#                                 'volumeUSD': '577854594925.0263620360667153467773'},
#                      'token0Price': '1.005969119835449977654336186589668',
#                      'token1': {'decimals': '6',
#                                 'feesUSD': '149273753.6304619810157594630976319',
#                                 'name': 'Tether USD',
#                                 'symbol': 'USDT',
#                                 'totalSupply': '18240',
#                                 'totalValueLocked': '130388279.784317',
#                                 'totalValueLockedUSD': '130388279.784317',
#                                 'volume': '163222783983.42327',
#                                 'volumeUSD': '163525342169.3596900748183408252995'},
#                      'token1Price': '0.9940662991360745066766188497012191',
#                      'totalValueLockedToken0': '29104794.070934',
#                      'totalValueLockedToken1': '3933240.890429',
#                      'totalValueLockedUSD': '33038034.961363'},
#                     {'createdAtTimestamp': '1622062029',
#                      'feeTier': '3000',
#                      'feesUSD': '4786657.554966859996912472606486181',
#                      'id': '0xa3f558aebaecaf0e11ca4b2199cc5ed341edfd74',
#                      'liquidity': '1681922246621902260892354',
#                      'liquidityProviderCount': '0',
#                      'tick': '-64217',
#                      'token0': {'decimals': '18',
#                                 'feesUSD': '11201799.64218177862812496864317517',
#                                 'name': 'Lido DAO Token',
#                                 'symbol': 'LDO',
#                                 'totalSupply': '28240',
#                                 'totalValueLocked': '8661148.154786834062192651',
#                                 'totalValueLockedUSD': '23922793.20006484672708503506546017',
#                                 'volume': '1120351491.059703789951282781',
#                                 'volumeUSD': '2260304290.056637394259601853078299'},
#                      'token0Price': '614.8469195048181376577438180413659',
#                      'token1': {'decimals': '18',
#                                 'feesUSD': '1183210897.988011021105904017405557',
#                                 'name': 'Wrapped Ether',
#                                 'symbol': 'WETH',
#                                 'totalSupply': '19848',
#                                 'totalValueLocked': '619211.810301398934441546',
#                                 'totalValueLockedUSD': '1051580807.277610276529651291639711',
#                                 'volume': '333052396.331927194386288771',
#                                 'volumeUSD': '734150905329.2055584971525209729411'},
#                      'token1Price': '0.001626421094872483425161644575244385',
#                      'totalValueLockedToken0': '6634202.444507388026691446',
#                      'totalValueLockedToken1': '7651.401715587332010925',
#                      'totalValueLockedUSD': '31318251.58227375397011614802043511'},
#                     {'createdAtTimestamp': '1620237038',
#                      'feeTier': '3000',
#                      'feesUSD': '15668735.22632541185522114149517631',
#                      'id': '0xa6cc3c2531fdaa6ae1a3ca84c2855806728693e8',
#                      'liquidity': '1337869553527861452060210',
#                      'liquidityProviderCount': '0',
#                      'tick': '-54914',
#                      'token0': {'decimals': '18',
#                                 'feesUSD': '16295514.95197701737299743550498425',
#                                 'name': 'ChainLink Token',
#                                 'symbol': 'LINK',
#                                 'totalSupply': '18240',
#                                 'totalValueLocked': '2567468.945012037559186583',
#                                 'totalValueLockedUSD': '17979545.09506813312827310672872618',
#                                 'volume': '443154018.086180849851679358',
#                                 'volumeUSD': '5428264880.213581778205616442438851'},
#                      'token0Price': '242.5101497969520510502433286376266',
#                      'token1': {'decimals': '18',
#                                 'feesUSD': '1183210897.988011021105904017405557',
#                                 'name': 'Wrapped Ether',
#                                 'symbol': 'WETH',
#                                 'totalSupply': '19848',
#                                 'totalValueLocked': '619211.810301398934441546',
#                                 'totalValueLockedUSD': '1051580807.277610276529651291639711',
#                                 'volume': '333052396.331927194386288771',
#                                 'volumeUSD': '734150905329.2055584971525209729411'},
#                      'token1Price': '0.004123538750181285548828175217810694',
#                      'totalValueLockedToken0': '2473908.662180761549184033',
#                      'totalValueLockedToken1': '6567.557029573400173398',
#                      'totalValueLockedUSD': '28477758.33317816066955031613898306'},
#                     {'createdAtTimestamp': '1620237823',
#                      'feeTier': '500',
#                      'feesUSD': '12651143.24234942079082461007118569',
#                      'id': '0x60594a405d53811d3bc4766596efd80fd545a270',
#                      'liquidity': '18052100513355741049091057',
#                      'liquidityProviderCount': '0',
#                      'tick': '-74378',
#                      'token0': {'decimals': '18',
#                                 'feesUSD': '61527317.98841803113568991968786631',
#                                 'name': 'Dai Stablecoin',
#                                 'symbol': 'DAI',
#                                 'totalSupply': '18240',
#                                 'totalValueLocked': '240275921.477541695991545732',
#                                 'totalValueLockedUSD': '240275921.477541695991545732',
#                                 'volume': '68489619888.976891834031522564',
#                                 'volumeUSD': '68524356395.81714613975479944686316'},
#                      'token0Price': '1698.252636929039113851032848141252',
#                      'token1': {'decimals': '18',
#                                 'feesUSD': '1183210897.988011021105904017405557',
#                                 'name': 'Wrapped Ether',
#                                 'symbol': 'WETH',
#                                 'totalSupply': '19848',
#                                 'totalValueLocked': '619211.810301398934441546',
#                                 'totalValueLockedUSD': '1051580807.277610276529651291639711',
#                                 'volume': '333052396.331927194386288771',
#                                 'volumeUSD': '734150905329.2055584971525209729411'},
#                      'token1Price': '0.0005888405401261771434115488319132791',
#                      'totalValueLockedToken0': '15579893.885975189588516509',
#                      'totalValueLockedToken1': '5865.553546761281477246',
#                      'totalValueLockedUSD': '25541111.4067310973413355126692554'},
#                     {'createdAtTimestamp': '1629152533',
#                      'feeTier': '3000',
#                      'feesUSD': '1014065.606613700891736470359483424',
#                      'id': '0x5c128d25a21f681e678cb050e551a895c9309945',
#                      'liquidity': '410244054867812553897830',
#                      'liquidityProviderCount': '0',
#                      'tick': '-80571',
#                      'token0': {'decimals': '18',
#                                 'feesUSD': '1093094.334952075518577915249962579',
#                                 'name': 'BitDAO',
#                                 'symbol': 'BIT',
#                                 'totalSupply': '28240',
#                                 'totalValueLocked': '23272006.633111339028259443',
#                                 'totalValueLockedUSD': '12527700.35325105886556032595694343',
#                                 'volume': '630198743.54906360502451025',
#                                 'volumeUSD': '354386956.79741196414629235620063'},
#                      'token0Price': '3154.756871076242486852585755713034',
#                      'token1': {'decimals': '18',
#                                 'feesUSD': '1183210897.988011021105904017405557',
#                                 'name': 'Wrapped Ether',
#                                 'symbol': 'WETH',
#                                 'totalSupply': '19848',
#                                 'totalValueLocked': '619211.810301398934441546',
#                                 'totalValueLockedUSD': '1051580807.277610276529651291639711',
#                                 'volume': '333052396.331927194386288771',
#                                 'volumeUSD': '734150905329.2055584971525209729411'},
#                      'token1Price': '0.0003169816378461047281269261592048285',
#                      'totalValueLockedToken0': '23237759.728458082453712678',
#                      'totalValueLockedToken1': '7354.617832155222714377',
#                      'totalValueLockedUSD': '24999296.09170768464262169823297105'},
#                     {'createdAtTimestamp': '1622219225',
#                      'feeTier': '500',
#                      'feesUSD': '452364.9121788910785314036177183706',
#                      'id': '0x97e7d56a0408570ba1a7852de36350f7713906ec',
#                      'liquidity': '4196081452233320376296887672',
#                      'liquidityProviderCount': '0',
#                      'tick': '4',
#                      'token0': {'decimals': '18',
#                                 'feesUSD': '61527317.98841803113568991968786631',
# ...
#                     {'createdAtTimestamp': '1620281753',
#                      'feeTier': '3000',
#                      'feesUSD': '4453565.150472062030465277554253349',
#                      'id': '0xf8a95b2409c27678a6d18d950c5d913d5c38ab03',
#                      'liquidity': '4218872108908538604',
#                      'liquidityProviderCount': '0',
#                      'tick': '124320',
#                      'token0': {'decimals': '8',
#                                 'feesUSD': '5748636.541847289807015977137306613',
#                                 'name': 'Gala',
#                                 'symbol': 'GALA',
#                                 'totalSupply': '28240',
#                                 'totalValueLocked': '45578115.91629398',
#                                 'totalValueLockedUSD': '1939379.607714606115131767091670103',
#                                 'volume': '15473299491.34183488',
#                                 'volumeUSD': '1619046120.980289854476829143056452'},
#                      'token0Price': '39911.40015488791861165115782179607',
#                      'token1': {'decimals': '18',
#                                 'feesUSD': '1183210897.988011021105904017405557',
#                                 'name': 'Wrapped Ether',
#                                 'symbol': 'WETH',
#                                 'totalSupply': '19848',
#                                 'totalValueLocked': '619211.810301398934441546',
#                                 'totalValueLockedUSD': '1051580807.277610276529651291639711',
#                                 'volume': '333052396.331927194386288771',
#                                 'volumeUSD': '734150905329.2055584971525209729411'},
#                      'token1Price': '0.00002505549783067509762193241372034592',
#                      'totalValueLockedToken0': '37733810.96210538',
#                      'totalValueLockedToken1': '1003.19837630509938368',
#                      'totalValueLockedUSD': '3309287.826034936113947034609225501'},
#                     {'createdAtTimestamp': '1622570958',
#                      'feeTier': '10000',
#                      'feesUSD': '4095524.440446896354445135942221057',
#                      'id': '0x2e4784446a0a06df3d1a040b03e1680ee266c35a',
#                      'liquidity': '22928868315365311212055',
#                      'liquidityProviderCount': '0',
#                      'tick': '-56671',
#                      'token0': {'decimals': '18',
#                                 'feesUSD': '4704546.357018676484042612552573738',
#                                 'name': 'Convex Token',
#                                 'symbol': 'CVX',
#                                 'totalSupply': '28240',
#                                 'totalValueLocked': '602260.323410652501533874',
#                                 'totalValueLockedUSD': '3538491.458027739826583112649244639',
#                                 'volume': '33544411.449840700661904837',
#                                 'volumeUSD': '495744838.7148752680970962880024742'},
#                      'token0Price': '289.0847045725335954002690195124027',
#                      'token1': {'decimals': '18',
#                                 'feesUSD': '1183210897.988011021105904017405557',
#                                 'name': 'Wrapped Ether',
#                                 'symbol': 'WETH',
#                                 'totalSupply': '19848',
#                                 'totalValueLocked': '619211.810301398934441546',
#                                 'totalValueLockedUSD': '1051580807.277610276529651291639711',
#                                 'volume': '333052396.331927194386288771',
#                                 'volumeUSD': '734150905329.2055584971525209729411'},
#                      'token1Price': '0.003459193738661092811116931182029089',
#                      'totalValueLockedToken0': '305319.868788746756998915',
#                      'totalValueLockedToken1': '881.779149870176778274',
#                      'totalValueLockedUSD': '3291541.069753513606098674544644931'},
#                     {'createdAtTimestamp': '1624622762',
#                      'feeTier': '10000',
#                      'feesUSD': '2963911.57436068',
#                      'id': '0x094a28b22e1b4218d590ea6fa916b3c5e670ba55',
#                      'liquidity': '207426594996',
#                      'liquidityProviderCount': '0',
#                      'tick': '-30751',
#                      'token0': {'decimals': '6',
#                                 'feesUSD': '532114681.817181633237908037807917',
#                                 'name': 'USD Coin',
#                                 'symbol': 'USDC',
#                                 'totalSupply': '19312',
#                                 'totalValueLocked': '801395568.310042',
#                                 'totalValueLockedUSD': '801395568.310042',
#                                 'volume': '578002542397.742837',
#                                 'volumeUSD': '577854594925.0263620360667153467773'},
#                      'token0Price': '0.2164835498456280841295211260435292',
#                      'token1': {'decimals': '4',
#                                 'feesUSD': '3182974.368988690164555120783962631',
#                                 'name': 'Ultra Token',
#                                 'symbol': 'UOS',
#                                 'totalSupply': '18240',
#                                 'totalValueLocked': '7473861.3651',
#                                 'totalValueLockedUSD': '1617968.03937093980711916040830098',
#                                 'volume': '428033799.5297',
#                                 'volumeUSD': '325447184.315460428628254297096126'},
#                      'token1Price': '4.61928862822643307308121421091514',
#                      'totalValueLockedToken0': '1702660.483376',
#                      'totalValueLockedToken1': '7141670.1555',
#                      'totalValueLockedUSD': '3248714.590465218720580444222371827'},
#                     {'createdAtTimestamp': '1620387118',
#                      'feeTier': '10000',
#                      'feesUSD': '3517989.494518552522182687847491198',
#                      'id': '0x5aaa28ca43c6646fd1403e508f0fca1d92357dde',
#                      'liquidity': '112920731430084425662313',
#                      'liquidityProviderCount': '0',
#                      'tick': '-97837',
#                      'token0': {'decimals': '18',
#                                 'feesUSD': '3575031.535769815292785071369298737',
#                                 'name': 'LCX',
#                                 'symbol': 'LCX',
#                                 'totalSupply': '28240',
#                                 'totalValueLocked': '25915259.419184352382344241',
#                                 'totalValueLockedUSD': '2481896.179638862685533894598350133',
#                                 'volume': '2857971690.578090098151152483',
#                                 'volumeUSD': '358066279.0461868424190632920182991'},
#                      'token0Price': '17733.44477413077213197562651382494',
#                      'token1': {'decimals': '18',
#                                 'feesUSD': '1183210897.988011021105904017405557',
#                                 'name': 'Wrapped Ether',
#                                 'symbol': 'WETH',
#                                 'totalSupply': '19848',
#                                 'totalValueLocked': '619211.810301398934441546',
#                                 'totalValueLockedUSD': '1051580807.277610276529651291639711',
#                                 'volume': '333052396.331927194386288771',
#                                 'volumeUSD': '734150905329.2055584971525209729411'},
#                      'token1Price': '0.00005639062307052614378856120974247684',
#                      'totalValueLockedToken0': '22328307.053319986098594347',
#                      'totalValueLockedToken1': '649.220759813953973414',
#                      'totalValueLockedUSD': '3240963.634453243745706830239180048'},
#                     {'createdAtTimestamp': '1621838933',
#                      'feeTier': '10000',
#                      'feesUSD': '7167428.156055768211007292209856124',
#                      'id': '0x5b97b125cf8af96834f2d08c8f1291bd47724939',
#                      'liquidity': '49940822501347864249715',
#                      'liquidityProviderCount': '0',
#                      'tick': '-78822',
#                      'token0': {'decimals': '18',
#                                 'feesUSD': '7602579.552343884491391046452819366',
#                                 'name': 'SAND',
#                                 'symbol': 'SAND',
#                                 'totalSupply': '28240',
#                                 'totalValueLocked': '2177976.393431053365239741',
#                                 'totalValueLockedUSD': '1410696.476274420136384139382940379',
#                                 'volume': '298648453.690517532767518908',
#                                 'volumeUSD': '842408756.8089008497990065151476239'},
#                      'token0Price': '2648.53489493891682470314134188126',
#                      'token1': {'decimals': '18',
#                                 'feesUSD': '1183210897.988011021105904017405557',
#                                 'name': 'Wrapped Ether',
#                                 'symbol': 'WETH',
#                                 'totalSupply': '19848',
#                                 'totalValueLocked': '619211.810301398934441546',
#                                 'totalValueLockedUSD': '1051580807.277610276529651291639711',
#                                 'volume': '333052396.331927194386288771',
#                                 'volumeUSD': '734150905329.2055584971525209729411'},
#                      'token1Price': '0.0003775672361013249952552079384537197',
#                      'totalValueLockedToken0': '1970333.830861323402602593',
#                      'totalValueLockedToken1': '1122.402063530979414349',
#                      'totalValueLockedUSD': '3201664.672433291095556999720717952'},
#                     {'createdAtTimestamp': '1629625232',
#                      'feeTier': '10000',
#                      'feesUSD': '778179.3023346139800725044831760082',
#                      'id': '0x4b62fa30fea125e43780dc425c2be5acb4ba743b',
#                      'liquidity': '2980413630749772702',
#                      'liquidityProviderCount': '0',
#                      'tick': '141714',
#                      'token0': {'decimals': '9',
#                                 'feesUSD': '885987.5591958400473712957612438326',
#                                 'name': 'Wrapped TON Coin',
#                                 'symbol': 'TONCOIN',
#                                 'totalSupply': '18240',
#                                 'totalValueLocked': '1073030.574758337',
#                                 'totalValueLockedUSD': '2599737.970657471516195346104679094',
#                                 'volume': '50628348.175938141',
#                                 'volumeUSD': '99425623.11575426327973246317199576'},
#                      'token0Price': '701.0312206516017949125341772115002',
#                      'token1': {'decimals': '18',
#                                 'feesUSD': '1183210897.988011021105904017405557',
#                                 'name': 'Wrapped Ether',
#                                 'symbol': 'WETH',
#                                 'totalSupply': '19848',
#                                 'totalValueLocked': '619211.810301398934441546',
#                                 'totalValueLockedUSD': '1051580807.277610276529651291639711',
#                                 'volume': '333052396.331927194386288771',
#                                 'volumeUSD': '734150905329.2055584971525209729411'},
#                      'token1Price': '0.001426469992407056553856036469260072',
#                      'totalValueLockedToken0': '1013807.972410936',
#                      'totalValueLockedToken1': '425.930091964118382155',
#                      'totalValueLockedUSD': '3179677.896983721933187268697913079'},
#                     {'createdAtTimestamp': '1676406647',
#                      'feeTier': '3000',
#                      'feesUSD': '604399.609641894',
#                      'id': '0x92ab871abb9d567aa276b2ce58d0203d84e0181e',
#                      'liquidity': '4544532792846069753',
#                      'liquidityProviderCount': '0',
#                      'tick': '-280748',
#                      'token0': {'decimals': '18',
#                                 'feesUSD': '5717077.086508029283402511358930234',
#                                 'name': 'Blur',
#                                 'symbol': 'BLUR',
#                                 'totalSupply': '28368',
#                                 'totalValueLocked': '13627228.265900914819994717',
#                                 'totalValueLockedUSD': '8759446.412232225769419902761448463',
#                                 'volume': '1483623330.383659384139397882',
#                                 'volumeUSD': '1289062196.3371740363527399686271'},
#                      'token0Price': '1.556275397429929558171876774066037',
#                      'token1': {'decimals': '6',
#                                 'feesUSD': '532114681.817181633237908037807917',
#                                 'name': 'USD Coin',
#                                 'symbol': 'USDC',
#                                 'totalSupply': '19312',
#                                 'totalValueLocked': '801395568.310042',
#                                 'totalValueLockedUSD': '801395568.310042',
#                                 'volume': '578002542397.742837',
#                                 'volumeUSD': '577854594925.0263620360667153467773'},
#                      'token1Price': '0.6425597947840234033652162195413312',
#                      'totalValueLockedToken0': '3445919.214471146778608575',
#                      'totalValueLockedToken1': '938242.247407',
#                      'totalValueLockedUSD': '3153244.749094810965001965318259058'},
#                     {'createdAtTimestamp': '1621839430',
#                      'feeTier': '500',
#                      'feesUSD': '3103426.503904903542704759602401267',
#                      'id': '0x8c54aa2a32a779e6f6fbea568ad85a19e0109c26',
#                      'liquidity': '16671898624965676',
#                      'liquidityProviderCount': '0',
#                      'tick': '-276370',
#                      'token0': {'decimals': '18',
#                                 'feesUSD': '9019193.35965510946370846551966828',
#                                 'name': 'Fei USD',
#                                 'symbol': 'FEI',
#                                 'totalSupply': '18240',
#                                 'totalValueLocked': '4551901.365215728261594492',
#                                 'totalValueLockedUSD': '4551901.365215728261594492',
#                                 'volume': '10419616605.2239325749497106',
#                                 'volumeUSD': '10383565917.531471114841526822882'},
#                      'token0Price': '1.004533733737648363978484321324341',
#                      'token1': {'decimals': '6',
#                                 'feesUSD': '532114681.817181633237908037807917',
#                                 'name': 'USD Coin',
#                                 'symbol': 'USDC',
#                                 'totalSupply': '19312',
#                                 'totalValueLocked': '801395568.310042',
#                                 'totalValueLockedUSD': '801395568.310042',
#                                 'volume': '578002542397.742837',
#                                 'volumeUSD': '577854594925.0263620360667153467773'},
#                      'token1Price': '0.9954867282348206056264817788819045',
#                      'totalValueLockedToken0': '1551840.542484592336738054',
#                      'totalValueLockedToken1': '1552891.886115',
#                      'totalValueLockedUSD': '3104732.428599592336738054'}]}}

# %%
pools = result['data']['pools']
token_cols = pools[0]['token0'].keys()
for idx,p in enumerate(pools):
    for x in ['token0', 'token1']:
        for c in token_cols:
            pools[idx][f'{x}_{c}'] = p[x][c]

# %%
df1 = pd.DataFrame(pools)
df1.drop(columns=['token0', 'token1'],inplace = True)

# %%
# Double checking fee tiers
df1.feeTier.value_counts()
# 0.01%, 0.05%, 0.3%, 1%
# Out:
# 3000     41
# 10000    31
# 500      19
# 100       9
# Name: feeTier, dtype: int64

# %%
df1.head(20)
# Out:
#                                             id createdAtTimestamp     tick  \
# 0   0x277667eb3e34f134adf870be9550e9f323d0dc24         1663808675  -161389
# 1   0xa850478adaace4c08fc61de44d8cf3b64f359bec         1625360210    46048
# 2   0x8c0411f2ad5470a66cb2e9c64536cfb8dcd54d51         1663808063   -69281
# 3   0x055284a4ca6532ecc219ac06b577d540c686669d         1663808363     None
# 4   0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640         1620250931   201945
# 5   0x8ad599c3a0ff1de082011efddc58f1908eb6e6d
# 0                                     0
# 1                                     0
# 2                                     0
# 3                                     0
# 4   1183210897.988011021105904017405557
# 5   1183210897.988011021105904017405557
# 6   1183210897.988011021105904017405557
# 7    532114681.817181633237908037807917
# 8    532114681.817181633237908037807917
# 9   1183210897.988011021105904017405557
# 10  149273753.6304619810157594630976319
# 11   532114681.817181633237908037807917
# 12  1016801.903065880882605665904890417
# 13  149273753.6304619810157594630976319
# 14   532114681.817181633237908037807917
# 15  1183210897.988011021105904017405557
# 16  1183210897.988011021105904017405557
# 17  149273753.6304619810157594630976319
# 18  1183210897.988011021105904017405557
# 19  149273753.6304619810157594630976319

# %%
# Look at the USDC/ETH 0.3% pool
POOL_ID = '0x8ad599c3a0ff1de082011efddc58f1908eb6e6d8'


TICK_BASE = 1.0001

# GraphQL query to get the pool information
query = """query pools($pool_id: ID!) {
  pools (where: {id: $pool_id}) {
    tick
    liquidity
    feeTier
    token0 {
      symbol
      decimals
    }
    token1 {
      symbol
      decimals
    }
  }
}"""



# Query the subgraph
req = urllib.request.Request(URL)
req.add_header('Content-Type', 'application/json; charset=utf-8')
jsondata = {"query": query, "variables": {"pool_id": POOL_ID}}
jsondataasbytes = json.dumps(jsondata).encode('utf-8')
req.add_header('Content-Length', len(jsondataasbytes))
response = urllib.request.urlopen(req, jsondataasbytes)
obj = json.load(response)
print(obj)
pool = obj['data']['pools'][0]

# Extract liquidity from the response
L = int(pool["liquidity"])
tick = int(pool["tick"])
tick_spacing = fee_tier_to_tick_spacing(int(pool["feeTier"]))

print("L={}".format(L))
print("tick={}".format(tick))

token0 = pool["token0"]["symbol"]
token1 = pool["token1"]["symbol"]
decimals0 = int(pool["token0"]["decimals"]) # USDC has 6 decimals
decimals1 = int(pool["token1"]["decimals"]) # WETH has 18 decimals

# Compute the tick range. This code would work as well in Python: `tick // TICK_SPACING * TICK_SPACING`
# However, using floor() is more portable.
bottom_tick = math.floor(tick / tick_spacing) * tick_spacing
top_tick = bottom_tick + tick_spacing

# Compute the current price and adjust it to a human-readable format
price = tick_to_price(tick)
adjusted_price = price / (10 ** (decimals1 - decimals0))

# Compute square roots of prices corresponding to the bottom and top ticks
sa = tick_to_price(bottom_tick // 2)
sb = tick_to_price(top_tick // 2)
sp = price ** 0.5

# Compute real amounts of the two assets
amount0 = L * (sb - sp) / (sp * sb)
amount1 = L * (sp - sa)

# Adjust them to a human-readable format
adjusted_amount0 = amount0 / 10 ** decimals0
adjusted_amount1 = amount1 / 10 ** decimals1

print("Current price: {:.6f} {} for 1 {} ({:.6f} {} for 1 {})".format(
    adjusted_price, token1, token0, 1 / adjusted_price, token0, token1))

print("Amounts at the current tick range: {:.2f} {} and {:.2f} {}".format(
    adjusted_amount0, token0, adjusted_amount1, token1))
# Out:
# {'data': {'pools': [{'tick': '201946', 'liquidity': '8558213679362796850', 'feeTier': '3000', 'token0': {'symbol': 'USDC', 'decimals': '6'}, 'token1': {'symbol': 'WETH', 'decimals': '18'}}]}}
# L=8558213679362796850
# tick=201946
# Current price: 0.000589 WETH for 1 USDC (1698.381094 USDC for 1 WETH)
# Amounts at the current tick range: 246788.57 USDC and 477.06 WETH
